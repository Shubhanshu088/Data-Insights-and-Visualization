# %%
import pandas as pd

# %%
from datetime import date as dt

# %%
import matplotlib.pyplot as ml

# %%
import seaborn as sb

# %%
data=pd.read_excel(r"D:\Data_Analysis\Python\assignment.xlsx")

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 1      2174        1954  Graduation         Single   46344        1         1
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2235  10870        1967  Graduation        Married   61223        0         1
# 2236   4001        1946         PhD       Together   64014        2         1
# 2237   7270        1981  Graduation       Divorced   56981        0         0
# 2238   8235        1956      Master       Together   69245        0         1
# 2239   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
con=data["Response"]==1
Accept=data[con]
Accept
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 8      4855        1974         PhD       Together   30351        1         0
# 15     2114        1946         PhD         Single   82800        0         0
# 33     7373        1952         PhD       Divorced   46610        0         2
# 39     2968        1943         PhD       Divorced   48948        0         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2194   7118        1957  Graduation        Married   73803        0         1
# 2198   2632        1954  Graduation        Married   50501        1         1
# 2202  11133        1973         PhD           YOLO   48432        0         1
# 2221   7366        1982      Master         Single   75777        0         0
# 2239   9405        1954         PhD        Married   52869        1         1
#
# ...

# %% [markdown]
# # There are 334 customer who accepted the offer in last campaign

# %%
Accept.shape[0]
# Out:
# 334

# %%
con1=data["Complain"]==1
con2=data["MntWines"]>300
people=data[con1 & con2]

# %% [markdown]
# # There are 5 customer who spent on wine more than 300 and complained in last 2 years

# %%
people.shape[0]
# Out:
# 5

# %%
con3=data["Marital_Status"]=="Single"
con4=data["Year_Birth"]>1983
status=data[con3|con4]

# %% [markdown]
# # There are 637 cutomers who either single or born after 1983

# %%
status.shape[0]
# Out:
# 637

# %%
avg=data.groupby("Marital_Status")[['Recency']].mean()

# %% [markdown]
# # Average Recency Based on their Marital Status

# %%
avg
# Out:
#                   Recency
# Marital_Status
# Absurd          53.000000
# Alone           30.333333
# Divorced        49.487069
# Married         48.277778
# Single          49.506250
# Together        50.106897
# Widow           49.142857
# YOLO             3.000000

# %%
avginc=data.groupby("Education")[['Income']].mean()

# %% [markdown]
# # Average Income based on Customers Education

# %%
avginc
# Out:
#                   Income
# Education
# 2n Cycle    47668.167488
# Basic       20306.259259
# Graduation  52693.821650
# Master      52878.108108
# PhD         56082.090535

# %% [markdown]
# # sum of money spent on sweet based on kids at home

# %%
sumsweet=data.groupby("Kidhome")[['MntSweetProducts']].sum()

# %%
sumsweet
# Out:
#          MntSweetProducts
# Kidhome
# 0                   52365
# 1                    8030
# 2                     226

# %%
sumgold=data.groupby("Marital_Status")[['MntGoldProds']].sum()

# %% [markdown]
# # Sum of gold Spent  Based on Marital Status

# %%
sumgold
# Out:
#                 MntGoldProds
# Marital_Status
# Absurd                   408
# Alone                     81
# Divorced               10739
# Married                36999
# Single                 20990
# Together               24937
# Widow                   4371
# YOLO                      84

# %% [markdown]
# # first we have to convert Dt_Customer	in datetime datatype

# %%
data.Dt_Customer=pd.to_datetime(data.Dt_Customer)

# %%
data.dtypes
# Out:
# ID                           int64
# Year_Birth                   int64
# Education                   object
# Marital_Status              object
# Income                       int64
# Kidhome                      int64
# Teenhome                     int64
# Dt_Customer         datetime64[ns]
# Recency                      int64
# MntWines                     int64
# MntFruits                    int64
# MntMeatProducts              int64
# MntFishProducts              int64
# MntSweetProducts             int64
# MntGoldProds                 int64
# Complain                     int64
# Response                     int64
# dtype: object

# %%
data["Day Name"]=data['Dt_Customer'].dt.day_name()

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 1      2174        1954  Graduation         Single   46344        1         1
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2235  10870        1967  Graduation        Married   61223        0         1
# 2236   4001        1946         PhD       Together   64014        2         1
# 2237   7270        1981  Graduation       Divorced   56981        0         0
# 2238   8235        1956      Master       Together   69245        0         1
# 2239   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
avgrece=data.groupby('Day Name')[['Recency']].mean()

# %% [markdown]
# # Average recency based on weekday

# %%
avgrece
# Out:
#              Recency
# Day Name
# Friday     50.939297
# Monday     46.201278
# Saturday   50.161184
# Sunday     50.383721
# Thursday   48.119874
# Tuesday    47.501587
# Wednesday  50.305389

# %%
data["Month"]=data["Dt_Customer"].dt.month_name()

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 1      2174        1954  Graduation         Single   46344        1         1
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2235  10870        1967  Graduation        Married   61223        0         1
# 2236   4001        1946         PhD       Together   64014        2         1
# 2237   7270        1981  Graduation       Divorced   56981        0         0
# 2238   8235        1956      Master       Together   69245        0         1
# 2239   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
summeat=data.groupby('Month')[['MntMeatProducts']].sum()

# %% [markdown]
# # total money Spent on meat based on month of year

# %%
summeat
# Out:
#            MntMeatProducts
# Month
# April                30724
# August               35102
# December             37247
# February             32748
# January              30557
# July                 19133
# June                 26937
# March                27504
# May                  33288
# November             35084
# October              33618
# September            32026

# %% [markdown]
# # Histogram representation Customer`s income

# %%
sb.histplot(data['Income'],kde=True)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %% [markdown]
# # Scatter Plot Between Customer Income and Recency

# %%
sb.scatterplot(data['Income'],data['Recency'])
# Out:
# C:\Users\Maddy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Income', ylabel='Recency'>

# %% [markdown]
# # Bar chart of average spent on fish based on teen lived in home

# %%
avgfish=data.groupby('Teenhome')[['MntFishProducts']].mean()

# %%
avgfish
# Out:
#           MntFishProducts
# Teenhome
# 0               48.658031
# 1               25.697087
# 2               23.903846

# %%
avgfish.plot.bar()
# Out:
# <AxesSubplot:xlabel='Teenhome'>
